# %%
from train import TrainPipeline

# %%
training_pipeline = TrainPipeline()
training_pipeline.run()
# Out:
# batch i:1, episode_len:74
# kl:0.00012,lr_multiplier:1.800,loss:6.691760063171387,entropy:1.2183191776275635,explained_var_old:0.000,explained_var_new:0.756
# batch i:2, episode_len:72
# kl:0.00226,lr_multiplier:2.700,loss:6.626723289489746,entropy:1.218345284461975,explained_var_old:0.756,explained_var_new:0.810
# batch i:3, episode_len:49
# kl:0.00109,lr_multiplier:4.050,loss:7.25252103805542,entropy:1.2179499864578247,explained_var_old:0.191,explained_var_new:0.179
# batch i:4, episode_len:59
# kl:0.00385,lr_multiplier:6.075,loss:7.298041820526123,entropy:1.2174968719482422,explained_var_old:-0.270,explained_var_new:0.000
# batch i:5, episode_len:43
# kl:0.00360,lr_multiplier:9.112,loss:7.264674186706543,entropy:1.2163695096969604,explained_var_old:0.000,explained_var_new:0.000
# batch i:6, episode_len:64
# kl:0.00335,lr_multiplier:13.669,loss:7.240477085113525,entropy:1.218422770500183,explained_var_old:0.000,explained_var_new:0.000
# batch i:7, episode_len:81
# ...
